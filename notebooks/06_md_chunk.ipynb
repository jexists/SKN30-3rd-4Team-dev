# %%
import os

# 현재 위치(notebooks/) 기준 상대 경로 설정
RAW_MD_DIR = "../data/01_raw/md"
OUTPUT_DIR = "../data/04_chunks"

# 저장할 폴더가 없으면 생성
os.makedirs(OUTPUT_DIR, exist_ok=True)

# 대상 마크다운 파일 목록 확인
md_files = [f for f in os.listdir(RAW_MD_DIR) if f.endswith('.md')]
print("찾은 마크다운 파일:", md_files)
# Out:
# 찾은 마크다운 파일: ['tilnote_2026년 전세 사기 예방 등기부등본 확인법 완벽 가이드_원본.md', 'tilnote_전세 사기 예방 등기부등본 확인법 초보 세입자 체크리스트.md']

# %%
from langchain_text_splitters import MarkdownHeaderTextSplitter

# 쪼갤 기준 헤더와 메타데이터 매핑
headers_to_split_on = [
    ("#", "Header_1"),
    ("##", "Header_2"),
    ("###", "Header_3"),
]

markdown_splitter = MarkdownHeaderTextSplitter(headers_to_split_on=headers_to_split_on)
